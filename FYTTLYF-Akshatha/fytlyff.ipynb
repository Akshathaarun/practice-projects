# %% [markdown]
# # Fytlyff_DS_Interview 2#

# %% [markdown]
# # IMPORTING NEEDED LIBRARIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import norm
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # CHECKING THE DATA ROWS AND COLUMNS

# %%
df=pd.read_csv("data.csv")

# %%
df
# Out:
#       Year Month MobileWeb_or_Web Type_of_Customers?  \
# 0     2019   Jan  Desktop_Website  Existing_Customer
# 1     2019   Jan  Desktop_Website  Existing_Customer
# 2     2019   Jan  Desktop_Website  Existing_Customer
# 3     2019   Jan  Desktop_Website  Existing_Customer
# 4     2019   Jan  Desktop_Website  Existing_Customer
# ...    ...   ...              ...                ...
# 2155  2021   Dec   Mobile_website       New_Customer
# 2156  2021   Dec   Mobile_website       New_Customer
# 2157  2021   Dec   Mobile_website       New_Customer
# 2158  2021   Dec   Mobile_website       New_Customer
# 2159  2021   Dec   Mobile_website       New_Customer
#
#      Where_Are_They_comming_from? Which_Place_in_India?  \
# 0                Came_From_Google             Bangalore
# 1                Came_From_Google               Chennai
# 2                Came_From_Google              Dehradun
# 3                Came_From_Google                Indore
# ...

# %%
df.head()
# Out:
#    Year Month MobileWeb_or_Web Type_of_Customers?  \
# 0  2019   Jan  Desktop_Website  Existing_Customer
# 1  2019   Jan  Desktop_Website  Existing_Customer
# 2  2019   Jan  Desktop_Website  Existing_Customer
# 3  2019   Jan  Desktop_Website  Existing_Customer
# 4  2019   Jan  Desktop_Website  Existing_Customer
#
#   Where_Are_They_comming_from? Which_Place_in_India?  \
# 0             Came_From_Google             Bangalore
# 1             Came_From_Google               Chennai
# 2             Came_From_Google              Dehradun
# 3             Came_From_Google                Indore
# 4             Came_From_Google                  Pune
#
#    How_many_Landed_on_our_Page?  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
#
#    How_many_Landed_on_the_our_Page_and_clicked_on_a_button?  \
# 0                                                NaN
# ...

# %%
df.tail()
# Out:
#       Year Month MobileWeb_or_Web Type_of_Customers?  \
# 2155  2021   Dec   Mobile_website       New_Customer
# 2156  2021   Dec   Mobile_website       New_Customer
# 2157  2021   Dec   Mobile_website       New_Customer
# 2158  2021   Dec   Mobile_website       New_Customer
# 2159  2021   Dec   Mobile_website       New_Customer
#
#      Where_Are_They_comming_from? Which_Place_in_India?  \
# 2155         Unidentified_Sources             Bangalore
# 2156         Unidentified_Sources               Chennai
# 2157         Unidentified_Sources              Dehradun
# 2158         Unidentified_Sources                Indore
# 2159         Unidentified_Sources                  Pune
#
#       How_many_Landed_on_our_Page?  \
# 2155                       67299.0
# 2156                      430294.0
# 2157                       48713.0
# 2158                      593021.0
# 2159                      372897.0
#
#       How_many_Landed_on_the_our_Page_and_clicked_on_a_button?  \
# ...

# %%
df.shape
# Out:
# (2160, 10)

# %%
df.dtypes
# Out:
# Year                                                                                                                           int64
# Month                                                                                                                         object
# MobileWeb_or_Web                                                                                                              object
# Type_of_Customers?                                                                                                            object
# Where_Are_They_comming_from?                                                                                                  object
# Which_Place_in_India?                                                                                                         object
# How_many_Landed_on_our_Page?                                                                                                 float64
# ...

# %%
df.columns
# Out:
# Index(['Year', 'Month', 'MobileWeb_or_Web', 'Type_of_Customers?',
#        'Where_Are_They_comming_from?', 'Which_Place_in_India?',
#        'How_many_Landed_on_our_Page?',
#        'How_many_Landed_on_the_our_Page_and_clicked_on_a_button?',
#        'How_many_Landed_on_the_our_Page_and_clicked_on_a_button_and_started_filling_the_Form?',
#        'How_many_Landed_on_the_our_Page_and_clicked_on_a_button_and_started_filling_the_Form_and_Completed_and_submited_the_form?'],
#       dtype='object')

# %% [raw]
# #)OUR DATA HAS 10 DIFFERENT COLUMNS AND 2160 DIFFERENT ROWS:::
# " Year', 'Month', 'MobileWeb_or_Web', 'Type_of_Customers?','Where_Are_They_comming_from?', 'Which_Place_in_India 'How_many_Landed_on_our_Page?','How_many_Landed_on_the_our_Page_and_clicked_on_a_button?','How_many_Landed_on_the_our_Page_and_clicked_on_a_button_and_started_filling_the_Form?
# How_many_Landed_on_the_our_Page_and_clicked_on_a_button_and_started_filling_the_Form_and_Completed_and_submited_the_form? are the different columns

# %% [raw]
# #)OUR DATA HAS 10 DIFFERENT COLUMNS AND 2160 DIFFERENT ROWS:::
# Year                                                                                                                           int64
# Month                                                                                                                         object
# MobileWeb_or_Web                                                                                                              object
# Type_of_Customers?                                                                                                            object
# Where_Are_They_comming_from?                                                                                                  object
# Which_Place_in_India?                                                                                                         object
# How_many_Landed_on_our_Page?                                                                                                 float64
# How_many_Landed_on_the_our_Page_and_clicked_on_a_button?                                                                     float64
# How_many_Landed_on_the_our_Page_and_clicked_on_a_button_and_started_filling_the_Form?                                          int64
# How_many_Landed_on_the_our_Page_and_clicked_on_a_button_and_started_filling_the_Form_and_Completed_and_submited_the_form?      int64

# %% [markdown]
# # checking for null variables

# %%
df.isnull().sum()
# Out:
# Year                                                                                                                            0
# Month                                                                                                                           0
# MobileWeb_or_Web                                                                                                                0
# Type_of_Customers?                                                                                                              0
# Where_Are_They_comming_from?                                                                                                    0
# Which_Place_in_India?                                                                                                           0
# How_many_Landed_on_our_Page?                                                                                                 1080
# ...

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [raw]
# while checking for null variables two columns have null values we have to treat those null values further,
# the columns with null values are:
#     1)How_many_Landed_on_our_Page?
#     2)How_many_Landed_on_the_our_Page_and_clicked_on_a_button?

# %% [markdown]
# # Descriptive statistics

# %%
df.describe()
# Out:
#               Year  How_many_Landed_on_our_Page?  \
# count  2160.000000                  1.080000e+03
# mean   2020.000000                  7.844949e+05
# std       0.816686                  1.232518e+06
# min    2019.000000                  2.456700e+04
# 25%    2019.000000                  1.406165e+05
# 50%    2020.000000                  3.818205e+05
# 75%    2021.000000                  8.196922e+05
# max    2021.000000                  1.127413e+07
#
#        How_many_Landed_on_the_our_Page_and_clicked_on_a_button?  \
# count                                       1.080000e+03
# mean                                        3.584563e+05
# std                                         4.981331e+05
# min                                         8.425000e+03
# 25%                                         8.060375e+04
# 50%                                         1.731775e+05
# 75%                                         3.948560e+05
# ...

# %% [markdown]
# AFTER ANALYSING EACH COLUMN WE CAN ANALYSE THE COLUMN

# %% [markdown]
# # DATA CLEANING

# %% [markdown]
# # CHANGING COLUMN CONTENT NAME

# %%
df["Where_Are_They_comming_from?"]
# Out:
# 0           Came_From_Google
# 1           Came_From_Google
# 2           Came_From_Google
# 3           Came_From_Google
# 4           Came_From_Google
#                 ...
# 2155    Unidentified_Sources
# 2156    Unidentified_Sources
# 2157    Unidentified_Sources
# 2158    Unidentified_Sources
# 2159    Unidentified_Sources
# Name: Where_Are_They_comming_from?, Length: 2160, dtype: object

# %%
df=df.replace({'Where_Are_They_comming_from?':{'Came_From_Google':"Google"}})

# %%
df=df.replace({'Where_Are_They_comming_from?':{'Landed_on_the_page_Directly':"Direct_traffic"}})

# %%
sns.countplot(df['Where_Are_They_comming_from?'])
print(df["Where_Are_They_comming_from?"].value_counts())
# Out:
# Unidentified_Sources    720
# Direct_traffic          720
# Google                  720
# Name: Where_Are_They_comming_from?, dtype: int64

# %% [markdown]
# FILLING NULL VALUES WITH "0"

# %%
df.isnull().sum()
# Out:
# Year                                                                                                                            0
# Month                                                                                                                           0
# MobileWeb_or_Web                                                                                                                0
# Type_of_Customers?                                                                                                              0
# Where_Are_They_comming_from?                                                                                                    0
# Which_Place_in_India?                                                                                                           0
# How_many_Landed_on_our_Page?                                                                                                 1080
# ...

# %%
df['How_many_Landed_on_our_Page?']=df['How_many_Landed_on_our_Page?'].fillna(0)

# %%
df['How_many_Landed_on_the_our_Page_and_clicked_on_a_button?']=df['How_many_Landed_on_the_our_Page_and_clicked_on_a_button?'].fillna(0)

# %%
df.isnull().sum()
# Out:
# Year                                                                                                                         0
# Month                                                                                                                        0
# MobileWeb_or_Web                                                                                                             0
# Type_of_Customers?                                                                                                           0
# Where_Are_They_comming_from?                                                                                                 0
# Which_Place_in_India?                                                                                                        0
# How_many_Landed_on_our_Page?                                                                                                 0
# ...

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# NOW THERE IS NO NULL VALUES IN DATA

# %% [markdown]
# # EDA -ANALYSIS

# %% [markdown]
# # *)COLUMN NAME:How_many_Landed_on_the_our_Page_and_clicked_on_a_button_and_started_filling_the_Form_and_Completed_and_submited_the_form?

# %%
df['How_many_Landed_on_the_our_Page_and_clicked_on_a_button_and_started_filling_the_Form_and_Completed_and_submited_the_form?']
# Out:
# 0        17178
# 1        11916
# 2        19461
# 3       110667
# 4        46033
#          ...
# 2155      1882
# 2156     16703
# 2157      2089
# 2158     78465
# 2159     19441
# Name: How_many_Landed_on_the_our_Page_and_clicked_on_a_button_and_started_filling_the_Form_and_Completed_and_submited_the_form?, Length: 2160, dtype: int64

# %% [markdown]
# THE COLUMN NAMED How_many_Landed_on_the_our_Page_and_clicked_on_a_button_and_started_filling_the_Form_and_Completed_and_submited_the_form? CONSISTING CONTINIOUS VALUES

# %%
sns.distplot(df['How_many_Landed_on_the_our_Page_and_clicked_on_a_button_and_started_filling_the_Form_and_Completed_and_submited_the_form?'],fit=norm)
# Out:
# <AxesSubplot:xlabel='How_many_Landed_on_the_our_Page_and_clicked_on_a_button_and_started_filling_the_Form_and_Completed_and_submited_the_form?', ylabel='Density'>

# %% [markdown]
# # 2)COLUMN:How_many_Landed_on_our_Page?

# %%
sns.distplot(df['How_many_Landed_on_our_Page?'],fit=norm)
# Out:
# <AxesSubplot:xlabel='How_many_Landed_on_our_Page?', ylabel='Density'>

# %% [markdown]
# # 3)COLUMN:How_many_Landed_on_the_our_Page_and_clicked_on_a_button?

# %%
sns.distplot(df['How_many_Landed_on_the_our_Page_and_clicked_on_a_button?'],fit=norm)
# Out:
# <AxesSubplot:xlabel='How_many_Landed_on_the_our_Page_and_clicked_on_a_button?', ylabel='Density'>

# %% [markdown]
# # 4)COLUMN:How_many_Landed_on_the_our_Page_and_clicked_on_a_button_and_started_filling_the_Form?

# %%
sns.distplot(df['How_many_Landed_on_the_our_Page_and_clicked_on_a_button_and_started_filling_the_Form?'],fit=norm)
# Out:
# <AxesSubplot:xlabel='How_many_Landed_on_the_our_Page_and_clicked_on_a_button_and_started_filling_the_Form?', ylabel='Density'>

# %% [markdown]
# # 5)COLUMN:Year

# %%
sns.countplot(df['Year'])
print(df["Year"].value_counts())
# Out:
# 2020    720
# 2019    720
# 2021    720
# Name: Year, dtype: int64

# %% [markdown]
# # 6)COLUMN:Month

# %%
sns.countplot(df['Month'])
print(df["Month"].value_counts())
# Out:
# Mar    180
# Nov    180
# Apr    180
# Feb    180
# Jun    180
# Aug    180
# Jul    180
# May    180
# Oct    180
# Sep    180
# Jan    180
# Dec    180
# Name: Month, dtype: int64

# %% [markdown]
# # 7)COLUMN:MobileWeb_or_Web

# %%
sns.countplot(df['MobileWeb_or_Web'])
print(df["MobileWeb_or_Web"].value_counts())
# Out:
# Desktop_Website    1080
# Mobile_website     1080
# Name: MobileWeb_or_Web, dtype: int64

# %% [markdown]
# # 8)COLUMN:Type_of_Customers?

# %%
sns.countplot(df['Type_of_Customers?'])
print(df["Type_of_Customers?"].value_counts())
# Out:
# New_Customer         1080
# Existing_Customer    1080
# Name: Type_of_Customers?, dtype: int64

# %% [markdown]
# # 9)COLUMN:Where_Are_They_comming_from?

# %%
sns.countplot(df['Where_Are_They_comming_from?'])
print(df["Where_Are_They_comming_from?"].value_counts())
# Out:
# Unidentified_Sources    720
# Direct_traffic          720
# Google                  720
# Name: Where_Are_They_comming_from?, dtype: int64

# %%
df["Where_Are_They_comming_from?"].replace(to_replace="came_from_google", value="google")
# Out:
# 0                     Google
# 1                     Google
# 2                     Google
# 3                     Google
# 4                     Google
#                 ...
# 2155    Unidentified_Sources
# 2156    Unidentified_Sources
# 2157    Unidentified_Sources
# 2158    Unidentified_Sources
# 2159    Unidentified_Sources
# Name: Where_Are_They_comming_from?, Length: 2160, dtype: object

# %% [markdown]
# # 10)column:Which_Place_in_India?

# %%
sns.countplot(df['Which_Place_in_India?'])
print(df["Which_Place_in_India?"].value_counts())
# Out:
# Indore       432
# Chennai      432
# Dehradun     432
# Pune         432
# Bangalore    432
# Name: Which_Place_in_India?, dtype: int64

# %% [markdown]
# # BIVARIATE ANALYSIS:VISUALIZATION

# %% [markdown]
# # Q1)“Which_Place_in_India?”  has the highest “How_many_Landed_on_the_our_Page?”

# %%
plt.figure(figsize=[10,6])
plt.title('How_many_Landed_on_our_Page? AND Which_Place_in_India?')
sns.scatterplot(df['How_many_Landed_on_our_Page?'],df['Which_Place_in_India?'],hue=df['Which_Place_in_India?'])
# Out:
# <AxesSubplot:title={'center':'How_many_Landed_on_our_Page? AND Which_Place_in_India?'}, xlabel='How_many_Landed_on_our_Page?', ylabel='Which_Place_in_India?'>

# %%
plt.figure(figsize=[10,6])
plt.title('How_many_Landed_on_our_Page? AND Which_Place_in_India?')
sns.scatterplot(df['Which_Place_in_India?'],df['How_many_Landed_on_our_Page?'],hue=df['Which_Place_in_India?'])
# Out:
# <AxesSubplot:title={'center':'How_many_Landed_on_our_Page? AND Which_Place_in_India?'}, xlabel='Which_Place_in_India?', ylabel='How_many_Landed_on_our_Page?'>

# %% [markdown]
# # ANS) FROM PUNE THE MOST NUMBER LANDED ON THE SITE

# %% [markdown]
# # ANALYSIS

# %% [markdown]
# # Q2)How_many_Landed_on_the_our_Page_and_clicked_on_a_button_and_started_filling_the_Form_and_Completed_and_submited_the_form?” divided by “How_many_Landed_on _our_Page?” is highest for “Which_Place_in_India?”

# %%
plt.figure(figsize=[10,6])
plt.title('How_many_Landed_on_the_our_Page_and_clicked_on_a_button_and_started_filling_the_Form? AND Which_Place_in_India?')
sns.scatterplot(df['Which_Place_in_India?'],df['How_many_Landed_on_the_our_Page_and_clicked_on_a_button_and_started_filling_the_Form?'],hue=df['Which_Place_in_India?'])
# Out:
# <AxesSubplot:title={'center':'How_many_Landed_on_the_our_Page_and_clicked_on_a_button_and_started_filling_the_Form? AND Which_Place_in_India?'}, xlabel='Which_Place_in_India?', ylabel='How_many_Landed_on_the_our_Page_and_clicked_on_a_button_and_started_filling_the_Form?'>

# %% [markdown]
# # ANS)EVEN IF PUNE IS THE PLACE WHERE MOST NUMBER OF PERSON LANDED ON PAGE,, HOWEVER """INDORE""" IS THE PLACE WHERE  MOST NUMBER OF PERSONS CLICKED THE BUTTON AND STARTED FILLING.

# %% [markdown]
# # Visualization

# %%
df.plot(x="Month", y=["How_many_Landed_on_the_our_Page_and_clicked_on_a_button?"], kind="line", figsize=(9, 8))
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
plt.figure(figsize=[10,6])
plt.title('How_many_Landed_on_the_our_Page_and_clicked_on_a_button? AND Which_Place_in_India?')
sns.scatterplot(df['How_many_Landed_on_the_our_Page_and_clicked_on_a_button?'],df['Which_Place_in_India?'],hue=df['Month'])
# Out:
# <AxesSubplot:title={'center':'How_many_Landed_on_the_our_Page_and_clicked_on_a_button? AND Which_Place_in_India?'}, xlabel='How_many_Landed_on_the_our_Page_and_clicked_on_a_button?', ylabel='Which_Place_in_India?'>

# %%
plt.figure(figsize=[10,6])
plt.title('How_many_Landed_on_the_our_Page_and_clicked_on_a_button? AND Which_Place_in_India?')
sns.lineplot(df['How_many_Landed_on_the_our_Page_and_clicked_on_a_button?'],df['Which_Place_in_India?'],hue=df['Month'])
# Out:
# <AxesSubplot:title={'center':'How_many_Landed_on_the_our_Page_and_clicked_on_a_button? AND Which_Place_in_India?'}, xlabel='How_many_Landed_on_the_our_Page_and_clicked_on_a_button?', ylabel='Which_Place_in_India?'>

# %% [markdown]
# # ENCODING

# %%
df.dtypes
# Out:
# Year                                                                                                                           int64
# Month                                                                                                                         object
# MobileWeb_or_Web                                                                                                              object
# Type_of_Customers?                                                                                                            object
# Where_Are_They_comming_from?                                                                                                  object
# Which_Place_in_India?                                                                                                         object
# How_many_Landed_on_our_Page?                                                                                                 float64
# ...

# %% [markdown]
# # WE WANT TO CONVERT OBJECT DATAS:CONVERTING MONTH NAME TO NUMBER

# %%
from sklearn.preprocessing import OrdinalEncoder
enc=OrdinalEncoder()

# %%
for i in df.columns:
    if df[i].dtypes=="object":
        df[i]=enc.fit_transform(df[i].values.reshape(-1,1))

# %%
df
# Out:
#       Year  Month  MobileWeb_or_Web  Type_of_Customers?  \
# 0     2019    4.0               0.0                 0.0
# 1     2019    4.0               0.0                 0.0
# 2     2019    4.0               0.0                 0.0
# 3     2019    4.0               0.0                 0.0
# 4     2019    4.0               0.0                 0.0
# ...    ...    ...               ...                 ...
# 2155  2021    2.0               1.0                 1.0
# 2156  2021    2.0               1.0                 1.0
# 2157  2021    2.0               1.0                 1.0
# 2158  2021    2.0               1.0                 1.0
# 2159  2021    2.0               1.0                 1.0
#
#       Where_Are_They_comming_from?  Which_Place_in_India?  \
# 0                              1.0                    0.0
# 1                              1.0                    1.0
# 2                              1.0                    2.0
# ...

# %%
sns.countplot(df['Month'])
print(df["Month"].value_counts())
# Out:
# 0.0     180
# 9.0     180
# 6.0     180
# 2.0     180
# 5.0     180
# 1.0     180
# 11.0    180
# 10.0    180
# 3.0     180
# 8.0     180
# 7.0     180
# 4.0     180
# Name: Month, dtype: int64

# %% [markdown]
# # TREATING OUTLIERS

# %% [raw]
# PLOTTING BOX PLOT FOR CHECKING OUTLIERS

# %%
sns.boxplot(df['How_many_Landed_on_our_Page?'])
# Out:
# <AxesSubplot:xlabel='How_many_Landed_on_our_Page?'>

# %%
sns.boxplot(df['How_many_Landed_on_the_our_Page_and_clicked_on_a_button?'])
# Out:
# <AxesSubplot:xlabel='How_many_Landed_on_the_our_Page_and_clicked_on_a_button?'>

# %%
sns.boxplot(df['How_many_Landed_on_the_our_Page_and_clicked_on_a_button_and_started_filling_the_Form?'])
# Out:
# <AxesSubplot:xlabel='How_many_Landed_on_the_our_Page_and_clicked_on_a_button_and_started_filling_the_Form?'>

# %%
sns.boxplot(df['How_many_Landed_on_the_our_Page_and_clicked_on_a_button_and_started_filling_the_Form_and_Completed_and_submited_the_form?'])
# Out:
# <AxesSubplot:xlabel='How_many_Landed_on_the_our_Page_and_clicked_on_a_button_and_started_filling_the_Form_and_Completed_and_submited_the_form?'>

# %%
sns.boxplot(df['Month'])
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
sns.boxplot(df['MobileWeb_or_Web'])
# Out:
# <AxesSubplot:xlabel='MobileWeb_or_Web'>

# %% [markdown]
# FROM BOX PLOTS IT IS CLEAR THAT OUTLIERS ARE THERE IN NUMERIC VALUES

# %% [markdown]
# SO WE HAVE TO TREAT OUTLIERS

# %%
from scipy.stats import zscore

# %%
z=np.abs(zscore(df))

# %%
new_df=df[(z<3).all(axis=1)]

# %%
new_df.shape
# Out:
# (2071, 10)

# %% [raw]
# very less percentage of loss is happened so we can proceed

# %% [markdown]
# # CORRELATION AND HEATMAP

# %%
df.describe()
# Out:
#               Year        Month  MobileWeb_or_Web  Type_of_Customers?  \
# count  2160.000000  2160.000000       2160.000000         2160.000000
# mean   2020.000000     5.500000          0.500000            0.500000
# std       0.816686     3.452852          0.500116            0.500116
# min    2019.000000     0.000000          0.000000            0.000000
# 25%    2019.000000     2.750000          0.000000            0.000000
# 50%    2020.000000     5.500000          0.500000            0.500000
# 75%    2021.000000     8.250000          1.000000            1.000000
# max    2021.000000    11.000000          1.000000            1.000000
#
#        Where_Are_They_comming_from?  Which_Place_in_India?  \
# count                   2160.000000            2160.000000
# mean                       1.000000               2.000000
# std                        0.816686               1.414541
# min                        0.000000               0.000000
# ...

# %%
cor=new_df.corr()

# %%
cor
# Out:
#                                                         Year     Month  \
# Year                                                1.000000 -0.002925
# Month                                              -0.002925  1.000000
# MobileWeb_or_Web                                    0.000827 -0.004365
# Type_of_Customers?                                 -0.020374 -0.004761
# Where_Are_They_comming_from?                        0.026571  0.005867
# Which_Place_in_India?                              -0.013253 -0.000756
# How_many_Landed_on_our_Page?                        0.001366  0.004889
# How_many_Landed_on_the_our_Page_and_clicked_on_... -0.091203  0.009484
# How_many_Landed_on_the_our_Page_and_clicked_on_... -0.066800  0.022368
# How_many_Landed_on_the_our_Page_and_clicked_on_... -0.079471  0.007665
#
#                                                     MobileWeb_or_Web  \
# Year                                                        0.000827
# ...

# %%
plt.figure(figsize=(30,15))
sns.heatmap(cor,annot=True,linewidths=0.1,linecolor="blue",fmt="0.2f")
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(22,7))
cor['How_many_Landed_on_the_our_Page_and_clicked_on_a_button_and_started_filling_the_Form_and_Completed_and_submited_the_form?'].sort_values(ascending=False).drop(['How_many_Landed_on_the_our_Page_and_clicked_on_a_button_and_started_filling_the_Form_and_Completed_and_submited_the_form?']).plot(kind='bar',color='r')
plt.xlabel('Feature',fontsize=14)
plt.ylabel('column with How_many_Landed_on_the_our_Page_and_clicked_on_a_button_and_started_filling_the_Form_and_Completed_and_submited_the_form?',fontsize=14)
plt.title('correlation',fontsize=18)
plt.show()

# %% [markdown]
# # by analysing correlation and dependency we have to drop some negatively correlated columns and some unwanted columns

# %%
new_df.drop(['Year'],axis=1,inplace=True)
new_df.drop(['Where_Are_They_comming_from?'],axis=1,inplace=True)

# %% [markdown]
# # SKEWNESS REMOVAL

# %%
new_df.skew()
# Out:
# Month                                                                                                                        0.005840
# MobileWeb_or_Web                                                                                                            -0.024162
# Type_of_Customers?                                                                                                           0.086091
# Which_Place_in_India?                                                                                                        0.054274
# How_many_Landed_on_our_Page?                                                                                                 2.968357
# How_many_Landed_on_the_our_Page_and_clicked_on_a_button?                                                                     2.696858
# How_many_Landed_on_the_our_Page_and_clicked_on_a_button_and_started_filling_the_Form?                                        2.046520
# ...

# %% [markdown]
# SOME COLUMNS LIKE How_many_Landed_on_our_Page?,How_many_Landed_on_the_our_Page_and_clicked_on_a_button?,How_many_Landed_on_the_our_Page_and_clicked_on_a_button_and_started_filling_the_Form?, HAVE SKEWNESS

# %% [markdown]
# # HISTOGRAM SHOWS THE SKEWNESS PRESENCE IN  THESE COLUMNS

# %%
new_df['How_many_Landed_on_our_Page?'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# FIGURE SHOWS THE SKEWNESS

# %%
new_df['How_many_Landed_on_the_our_Page_and_clicked_on_a_button?'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
new_df['How_many_Landed_on_the_our_Page_and_clicked_on_a_button_and_started_filling_the_Form?'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
new_df['How_many_Landed_on_the_our_Page_and_clicked_on_a_button_and_started_filling_the_Form_and_Completed_and_submited_the_form?'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# ALL ABOVE FIGURE SHOWS THE SKEWNESS

# %% [markdown]
# # SPLITTING X AND Y AND APPLYING POWER TRANSFORM FOR SKEWNES REMOVAL

# %%
from sklearn.preprocessing import PowerTransformer

# %%
x=new_df.drop("How_many_Landed_on_the_our_Page_and_clicked_on_a_button_and_started_filling_the_Form_and_Completed_and_submited_the_form?",axis=1)
y=new_df["How_many_Landed_on_the_our_Page_and_clicked_on_a_button_and_started_filling_the_Form_and_Completed_and_submited_the_form?"]

# %%
x
# Out:
#       Month  MobileWeb_or_Web  Type_of_Customers?  Which_Place_in_India?  \
# 0       4.0               0.0                 0.0                    0.0
# 1       4.0               0.0                 0.0                    1.0
# 2       4.0               0.0                 0.0                    2.0
# 3       4.0               0.0                 0.0                    3.0
# 4       4.0               0.0                 0.0                    4.0
# ...     ...               ...                 ...                    ...
# 2155    2.0               1.0                 1.0                    0.0
# 2156    2.0               1.0                 1.0                    1.0
# 2157    2.0               1.0                 1.0                    2.0
# 2158    2.0               1.0                 1.0                    3.0
# 2159    2.0               1.0                 1.0                    4.0
#
#       How_many_Landed_on_our_Page?  \
# 0                              0.0
# ...

# %%
y
# Out:
# 0        17178
# 1        11916
# 2        19461
# 3       110667
# 4        46033
#          ...
# 2155      1882
# 2156     16703
# 2157      2089
# 2158     78465
# 2159     19441
# Name: How_many_Landed_on_the_our_Page_and_clicked_on_a_button_and_started_filling_the_Form_and_Completed_and_submited_the_form?, Length: 2071, dtype: int64

# %%
x.shape
# Out:
# (2071, 7)

# %%
y.shape
# Out:
# (2071,)

# %%
pt=PowerTransformer(method="yeo-johnson")

# %%
X_power=pt.fit_transform(x)

# %%
df1=pd.DataFrame(X_power,columns=x.columns)

# %%
df1.skew()
# Out:
# Month                                                                                   -0.214622
# MobileWeb_or_Web                                                                        -0.024162
# Type_of_Customers?                                                                       0.086091
# Which_Place_in_India?                                                                   -0.158645
# How_many_Landed_on_our_Page?                                                             0.114827
# How_many_Landed_on_the_our_Page_and_clicked_on_a_button?                                 0.115319
# How_many_Landed_on_the_our_Page_and_clicked_on_a_button_and_started_filling_the_Form?   -0.010520
# dtype: float64

# %% [markdown]
# now skewness in good range

# %% [markdown]
# # train test split

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=45)

# %%
x_train.shape
# Out:
# (1449, 7)

# %%
x_test.shape
# Out:
# (622, 7)

# %%
y_train.shape
# Out:
# (1449,)

# %%
y_test.shape
# Out:
# (622,)

# %% [markdown]
# # APPLYING  ALGORITHMS

# %% [markdown]
# # LINEAR REGRESSION

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
lm=LinearRegression()

# %%
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred=lm.predict(x_test)

# %%
print(pred)
# Out:
# [ 1.03020752e+05  9.75059281e+04  2.87469590e+04  5.97631081e+03
#   8.14634086e+04  2.27544483e+04  7.96016650e+03  4.47834700e+04
#  -1.54121772e+03  3.08196368e+04  1.36480153e+04  2.40224891e+04
#   2.30559311e+04  2.63180828e+04  3.39384708e+04  5.31309666e+03
#   2.90945633e+04  6.62556022e+04  1.31038022e+04 -5.08098667e+02
#   1.53126825e+05  1.80303562e+04  2.11623687e+04  8.77824223e+04
#   3.05788003e+04  5.16693190e+04  1.98223873e+04  7.57548751e+03
#   3.78144620e+04  1.59687675e+04  4.34727322e+04  3.07528375e+04
#   2.88950783e+04  1.16918019e+04  2.15328394e+03  6.52678842e+03
#   2.72386364e+05 -1.85494339e+03  1.55689321e+04  1.14616018e+04
#   4.67524534e+04  4.49831256e+01  2.30150221e+04  7.54539985e+03
#   1.72321688e+04  1.91681228e+04  1.09043688e+04  1.40549880e+04
#   3.19687567e+04  4.23900827e+04 -2.02476986e+02  1.26613475e+03
#   2.49619380e+04  5.48517776e+04  3.13871029e+04  1.26502270e+04
# ...

# %%
print("mean absolute error:",mean_absolute_error(y_test,pred))
# Out:
# mean absolute error: 11962.511367567222

# %%
print("mean squred error:",mean_squared_error(y_test,pred))
# Out:
# mean squred error: 352086406.10915804

# %%
print("root mean squared error:",np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# root mean squared error: 18763.9656285434

# %% [markdown]
# # r2 score

# %%
from sklearn.metrics import r2_score

# %%
lmscore=r2_score(y_test,pred)

# %%
print(lmscore)
# Out:
# 0.8908320782313748

# %% [markdown]
# # DECISION TREE REGRESSOR

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dtr=DecisionTreeRegressor()

# %%
dtr.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
dtrpred=dtr.predict(x_test)

# %%
print(dtrpred)
# Out:
# [ 59787.  98546.  25390.   6850.  76841.  22450.  10298.  36698.   3888.
#   22362.   5196.  12734.  16123.  18680.  45623.   3762.  32291.  48710.
#   11763.   4851. 188298.  19771.  42052.  98229.  37718.  53381.  24658.
#    9286.  38788.   8755.  55910.  29664.  21858.  18370.   9562.  14036.
#  311586.   1201.   5643.  24240.  24409.   3548.  19448.   4627.  33468.
#   21913.  14429.  21697.  22362.  63272.   3915.   6203.  21151.  35556.
#   27930.   3698.   4560.  60175.  10743.  15928.  11815.  82153.  12103.
#    6636.  22180.  25254.  81979. 287063.   2460.  80021.  12734.  11831.
#   11062. 232852.  12481.  20064.  28268.   3704.  53115.  29099.   3704.
#   11126.  32928.  70801.  23072.   7986.   2104. 220093.  20024.  29718.
#   15595.  86289.  81979.   8275.  66225. 137863.  42002.  25254.  72032.
#   16727.  15067.  37972.  25390.  57540.  29507.   2362.   8253.   2648.
#    3704.  44563.  17741.  26296.  19945.  12901.   6624.  17210.  22148.
# ...

# %%
print("mean absolute error:",mean_absolute_error(y_test,dtrpred))
# Out:
# mean absolute error: 7862.82154340836

# %%
print("mean squred error:",mean_squared_error(y_test,dtrpred))
# Out:
# mean squred error: 321184664.67363346

# %%
print("root mean squared error:",np.sqrt(mean_squared_error(y_test,dtrpred)))
# Out:
# root mean squared error: 17921.625614704528

# %%
dtrscore=r2_score(y_test,dtrpred)

# %%
print(dtrscore)
# Out:
# 0.9004134731191449

# %% [markdown]
# # K-neighbor regressor

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
knnr=KNeighborsRegressor()

# %%
knnr.fit(x_train,y_train)
# Out:
# KNeighborsRegressor()

# %%
knnrpred=knnr.predict(x_test)

# %%
print(knnrpred)
# Out:
# [ 92416.  122003.8  18854.   14309.2  88523.6  20070.4  15231.   47737.
#    2354.4  29012.6  15021.4  12404.6  17962.   37817.4  37491.4   2519.4
#   30878.6  79834.6  16618.6   5457.4 186456.8  15880.4  31161.6 115277.2
#   31864.8  48637.6  26801.4   8539.2  53168.2   6577.6  47522.4  22968.2
#   20782.8  16376.4   6264.2   9199.6 276999.6   1263.   10930.8  18625.4
#   34444.8   2854.   14684.4   4506.4  19392.4  23036.2  16618.6  21409.
#   29012.6  50022.2   5325.6   5423.4  18676.4  80213.6  31992.2   6138.6
#    5185.   91106.8   6315.6  13630.8   6625.  104242.6   7992.4  11232.8
#   17805.   37774.6  83364.4 268108.8   2409.   95046.8  10675.4  15536.6
#   11848.2 247961.   13391.   56798.2  27528.2   2029.8  45702.6  39930.2
#    2664.6   9902.6  33431.4  49128.8  37817.4   6355.    2310.8 223859.6
#   18664.8  42144.4  11964.  109037.2  87803.6   6510.8  75783.6  97171.6
#   61840.4  33515.   85341.8  29801.4  16906.6  44184.   24586.  161757.4
# ...

# %%
print("mean absolute error:",mean_absolute_error(y_test,knnrpred))
# Out:
# mean absolute error: 8725.165594855305

# %%
print("mean squred error:",mean_squared_error(y_test,knnrpred))
# Out:
# mean squred error: 282470730.69163984

# %%
print("root mean squared error:",np.sqrt(mean_squared_error(y_test,knnrpred)))
# Out:
# root mean squared error: 16806.865582006652

# %%
knnrscore=r2_score(y_test,knnrpred)

# %%
print(knnrscore)
# Out:
# 0.9124171166650752

# %% [markdown]
# # CROSS VALIDATION MEAN SCORE

# %%
from sklearn.model_selection import cross_val_score

# %%
print(cross_val_score(lm,x,y,cv=5).mean())
# Out:
# 0.863128029726749

# %%
print(cross_val_score(dtr,x,y,cv=5).mean())
# Out:
# 0.8642623238010465

# %%
print(cross_val_score(knnr,x,y,cv=5).mean())
# Out:
# 0.868232758135397

# %% [markdown]
# # HYPER PARAMETER TUNING FOR LINEAR REGRESSION

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameter={'fit_intercept':['bool'],
          'normalize':['bool'],
          'copy_X':['bool'],
           'n_jobs':[1,10,100,1000]}

# %%
GCV=GridSearchCV(LinearRegression(),parameter,cv=5)

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=LinearRegression(),
#              param_grid={'copy_X': ['bool'], 'fit_intercept': ['bool'],
#                          'n_jobs': [1, 10, 100, 1000], 'normalize': ['bool']})

# %%
GCV.best_params_
# Out:
# {'copy_X': 'bool', 'fit_intercept': 'bool', 'n_jobs': 1, 'normalize': 'bool'}

# %%
Finalmodel=LinearRegression(copy_X='bool',
 fit_intercept='bool',
 normalize='bool',
  n_jobs=1)

# %%
Finalmodel.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X='bool', fit_intercept='bool', n_jobs=1,
#                  normalize='bool')

# %%
Finalpred=Finalmodel.predict(x_test)

# %%
Finalr2score=r2_score(y_test,Finalpred)

# %%
print(Finalr2score)
# Out:
# 0.8908320782319356

# %% [markdown]
# # saving and conclusion of model

# %%
Finalconclusion=pd.DataFrame([Finalmodel.predict(x_test)[:],Finalpred[:]],index=["Predicted","Orginal"])

# %%
Finalconclusion
# Out:
#                      0            1            2            3             4    \
# Predicted  103020.751558  97505.92811  28746.95897  5976.310806  81463.408617
# Orginal    103020.751558  97505.92811  28746.95897  5976.310806  81463.408617
#
#                     5            6             7            8             9    \
# Predicted  22754.448331  7960.166502  44783.469951 -1541.217722  30819.636759
# Orginal    22754.448331  7960.166502  44783.469951 -1541.217722  30819.636759
#
#            ...          612           613          614           615  \
# Predicted  ...  4155.236407  44804.754095 -1031.516296  29729.364637
# Orginal    ...  4155.236407  44804.754095 -1031.516296  29729.364637
#
#                     616          617          618         619           620  \
# Predicted  24027.890914  36856.66088 -1497.246532  27068.0954  43422.953993
# Orginal    24027.890914  36856.66088 -1497.246532  27068.0954  43422.953993
#
#                     621
# Predicted  93863.530582
# ...

# %% [markdown]
# SAVING

# %%
import joblib

# %%
joblib.dump(Finalmodel,"Finalmodel.obj")
# Out:
# ['Finalmodel.obj']
