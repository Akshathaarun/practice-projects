# %% [markdown]
# # Abalone Project

# %% [markdown]
# HERE IMPORTING THE WANTED LIBRARIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# NOW WE HAVE TO READ THE DATASET

# %%
df=pd.read_csv("projectAbalone.csv")

# %%
df
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %% [markdown]
# ANALYSING THE DATASET

# %%
df.head
# Out:
# <bound method NDFrame.head of      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# ...

# %%
df.sample(3)
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 2523   F   0.565      0.44   0.150        0.9830          0.4475
# 2128   M   0.620      0.51   0.175        1.1505          0.4375
# 3948   F   0.530      0.40   0.165        0.7720          0.2855
#
#       Viscera weight  Shell weight  Rings
# 2523          0.2355        0.2485      9
# 2128          0.2265        0.4000     12
# 3948          0.1975        0.2300     12

# %%
df.shape
# Out:
# (4177, 9)

# %%
df.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %% [markdown]
# there is no null value in the columns

# %% [markdown]
# # DATA FRAME DESCRIPTION

# %% [markdown]
# THE ABALONE DATA HAS 4177 ROWS AND 9 COLUMNS IT EXPLAINING THE DIFFERENT DEPENDENT VARIABLES OF AGE(RING)OF ABALONE
# SEX,LENGTH,DIAMETER,HEIGHT,WHOLE WEIGHT,SHUCKED WEIGHT,VISERS WEIGHT ARE THE PARAMETERS DEPENDING RINGS

# %% [markdown]
# DATA TYPES

# %%
df.dtypes
# Out:
# Sex                object
# Length            float64
# Diameter          float64
# Height            float64
# Whole weight      float64
# Shucked weight    float64
# Viscera weight    float64
# Shell weight      float64
# Rings               int64
# dtype: object

# %% [markdown]
# HERE ONE COLUMN IS IN STRING FORMAT ALL OTHERS ARE IN FLOAT DATA FORMAT AND OUR TARGET IS IN INT FORMAT

# %% [markdown]
# HERE GOING TO ANALYSE THE TARGET

# %%
df['Rings']
# Out:
# 0       15
# 1        7
# 2        9
# 3       10
# 4        7
#         ..
# 4172    11
# 4173    10
# 4174     9
# 4175    10
# 4176    12
# Name: Rings, Length: 4177, dtype: int64

# %%
df['Rings'].unique()
# Out:
# array([15,  7,  9, 10,  8, 20, 16, 19, 14, 11, 12, 18, 13,  5,  4,  6, 21,
#        17, 22,  1,  3, 26, 23, 29,  2, 27, 25, 24])

# %% [markdown]
# it has continues type of data,so regression technique is suggesting

# %% [markdown]
# # EDA

# %% [markdown]
# # UNIVARIATE ANALYSIS

# %% [markdown]
# here object data can analyse by count plot

# %%
sn.countplot(df["Sex"])
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %% [markdown]
# we have to encode the sex column,we have to convert the object column to float

# %% [markdown]
# string datas can be analyse by distribution plot

# %%
sn.displot(df['Length'])

# %% [markdown]
# Length has slight negative skewness

# %%
sn.displot(df['Diameter'])

# %% [markdown]
# Diameter having negative skewness

# %%
sn.displot(df['Height'])

# %% [markdown]
# data is normally distributed,but the presence of outliers are there

# %%
sn.displot(df['Whole weight'])

# %% [markdown]
# almost normally distributed,but slight positive skewness is there

# %%
sn.displot(df['Shucked weight'])

# %% [markdown]
# Shucked weight almost normally distributed,here also positive skewness is there

# %%
sn.displot(df['Viscera weight'])

# %% [markdown]
# Viscera weight has normally distributed values

# %%
sn.displot(df['Shell weight'])

# %% [markdown]
# Shell weight is normally distributed

# %% [markdown]
# # BOX PLOTS FOR ANALYSING OUTLIER PRESENCE

# %%
sn.boxplot(df['Length'])
# Out:
# <AxesSubplot:xlabel='Length'>

# %% [markdown]
# PRESENCE OF OUTLIER IS VISIBKLE IN LENGTH BOX PLOT

# %%
sn.boxplot(df['Diameter'])
# Out:
# <AxesSubplot:xlabel='Diameter'>

# %% [markdown]
# Diameter ALSO HAVING OUTLIER CONTENT

# %%
sn.boxplot(df['Height'])
# Out:
# <AxesSubplot:xlabel='Height'>

# %% [markdown]
# BOTH POSITIVE AND NEGATIVE OUTLIERS ARE PRESENT

# %%
sn.boxplot(df['Whole weight'])
# Out:
# <AxesSubplot:xlabel='Whole weight'>

# %% [markdown]
# Whole weight has outliers

# %%
sn.boxplot(df['Shucked weight'])
# Out:
# <AxesSubplot:xlabel='Shucked weight'>

# %% [markdown]
# Shucked weight has outliers

# %%
sn.boxplot(df['Viscera weight'])
# Out:
# <AxesSubplot:xlabel='Viscera weight'>

# %% [markdown]
# Viscera weight has outliers

# %%
sn.boxplot(df['Shell weight'])
# Out:
# <AxesSubplot:xlabel='Shell weight'>

# %% [markdown]
# Shell weigh has outliers

# %% [markdown]
# DIFFERENT UNIVARIATE ANALYSIS CLEARLY CONVEY THE PRESENCE OF OUTLIERS IN ALL COLUMNS

# %% [markdown]
# # BIVARIATE ANALYSIS

# %%
plt.figure(figsize=[10,6])
plt.title('comparison of Length and Height')
sn.scatterplot(df['Length'],df['Height'],hue=df['Rings'])
# Out:
# <AxesSubplot:title={'center':'comparison of Length and Height'}, xlabel='Length', ylabel='Height'>

# %%
plt.figure(figsize=[10,6])
plt.title('comparison of Length and Diameter')
sn.scatterplot(df['Length'],df['Diameter'],hue=df['Rings'])
# Out:
# <AxesSubplot:title={'center':'comparison of Length and Diameter'}, xlabel='Length', ylabel='Diameter'>

# %% [markdown]
# LENGTH AND HEIGHT & LENGTH AND DIAMETER HAVE LINEAR RELATIONSHIP

# %%
plt.figure(figsize=[10,6])
plt.title('comparison of Shucked weight and Shell weight')
sn.scatterplot(df['Shucked weight'],df['Shell weight'],hue=df['Rings'])
# Out:
# <AxesSubplot:title={'center':'comparison of Shucked weight and Shell weight'}, xlabel='Shucked weight', ylabel='Shell weight'>

# %%
plt.figure(figsize=[10,6])
plt.title('comparison of Shucked weight and Viscera weight')
sn.scatterplot(df['Shucked weight'],df['Viscera weight'],hue=df['Rings'])
# Out:
# <AxesSubplot:title={'center':'comparison of Shucked weight and Viscera weight'}, xlabel='Shucked weight', ylabel='Viscera weight'>

# %% [markdown]
# different weights also have some linear relatioship

# %% [markdown]
# # MULTIVARIATE ANALYSIS

# %%
sn.pairplot(df,hue="Rings")

# %% [markdown]
# from the pairplot it is clear that different columns have linear relation among them

# %% [markdown]
# # ENCODING OF DATA SET

# %%
df.dtypes
# Out:
# Sex                object
# Length            float64
# Diameter          float64
# Height            float64
# Whole weight      float64
# Shucked weight    float64
# Viscera weight    float64
# Shell weight      float64
# Rings               int64
# dtype: object

# %% [markdown]
# SEX is in object type data, we have to encode particular column

# %% [markdown]
# for encoding feature columns in object datatype the ORDINAL ENCODER is acceptable one

# %%
from sklearn.preprocessing import OrdinalEncoder
enc=OrdinalEncoder()

# %%
for i in df.columns:
    if df[i].dtypes=="object":
        df[i]=enc.fit_transform(df[i].values.reshape(-1,1))

# %%
df.dtypes
# Out:
# Sex               float64
# Length            float64
# Diameter          float64
# Height            float64
# Whole weight      float64
# Shucked weight    float64
# Viscera weight    float64
# Shell weight      float64
# Rings               int64
# dtype: object

# %%
df
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0     2.0   0.455     0.365   0.095        0.5140          0.2245
# 1     2.0   0.350     0.265   0.090        0.2255          0.0995
# 2     0.0   0.530     0.420   0.135        0.6770          0.2565
# 3     2.0   0.440     0.365   0.125        0.5160          0.2155
# 4     1.0   0.330     0.255   0.080        0.2050          0.0895
# ...   ...     ...       ...     ...           ...             ...
# 4172  0.0   0.565     0.450   0.165        0.8870          0.3700
# 4173  2.0   0.590     0.440   0.135        0.9660          0.4390
# 4174  2.0   0.600     0.475   0.205        1.1760          0.5255
# 4175  0.0   0.625     0.485   0.150        1.0945          0.5310
# 4176  2.0   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %%
df.describe()
# Out:
#                Sex       Length     Diameter       Height  Whole weight  \
# count  4177.000000  4177.000000  4177.000000  4177.000000   4177.000000
# mean      1.052909     0.523992     0.407881     0.139516      0.828742
# std       0.822240     0.120093     0.099240     0.041827      0.490389
# min       0.000000     0.075000     0.055000     0.000000      0.002000
# 25%       0.000000     0.450000     0.350000     0.115000      0.441500
# 50%       1.000000     0.545000     0.425000     0.140000      0.799500
# 75%       2.000000     0.615000     0.480000     0.165000      1.153000
# max       2.000000     0.815000     0.650000     1.130000      2.825500
#
#        Shucked weight  Viscera weight  Shell weight        Rings
# count     4177.000000     4177.000000   4177.000000  4177.000000
# mean         0.359367        0.180594      0.238831     9.933684
# std          0.221963        0.109614      0.139203     3.224169
# ...

# %% [markdown]
# THE DATAFRAME DESCRIPTION GIVES THE DETAILS OF MEAN MEDIAN AND STANDARD DEVIATIONS OF DIFFERENT COLUMNS

# %% [markdown]
# THE HUGE DEVIATION BETWEEN 75% AND MAX IN HEIGHT INTIMATING THE OUTLIER

# %% [markdown]
# # OUTLIER REMOVAL

# %%
from scipy.stats import zscore

# %%
z=np.abs(zscore(df))

# %%
new_df=df[(z<3).all(axis=1)]

# %%
new_df.shape
# Out:
# (4027, 9)

# %%
df.shape
# Out:
# (4177, 9)

# %% [markdown]
# less than 10 % loss happend so we can proceed

# %% [markdown]
# # SQEWNESS REMOVAL

# %% [markdown]
# WHEN ANALYSE THE DESCRIBE FUNCTION OF DATASET IT IS CLEAR THAT SKEWNESS IS PRESENT IN HEIGHT COLUMN

# %%
new_df.skew()
# Out:
# Sex              -0.094886
# Length           -0.623076
# Diameter         -0.598650
# Height           -0.244251
# Whole weight      0.334204
# Shucked weight    0.458295
# Viscera weight    0.437116
# Shell weight      0.349471
# Rings             0.725464
# dtype: float64

# %% [markdown]
# skewness is not present due to outlier removal

# %% [markdown]
# # CORRELATION CHECKING

# %%
cor=new_df.corr()

# %%
cor
# Out:
#                      Sex    Length  Diameter    Height  Whole weight  \
# Sex             1.000000 -0.043639 -0.046531 -0.046282     -0.034776
# Length         -0.043639  1.000000  0.986011  0.895432      0.934410
# Diameter       -0.046531  0.986011  1.000000  0.901803      0.934069
# Height         -0.046282  0.895432  0.901803  1.000000      0.891783
# Whole weight   -0.034776  0.934410  0.934069  0.891783      1.000000
# Shucked weight -0.016457  0.909245  0.904302  0.843010      0.971024
# Viscera weight -0.045292  0.907957  0.904192  0.869273      0.966612
# Shell weight   -0.043825  0.914518  0.921779  0.899716      0.961216
# Rings          -0.033272  0.567074  0.584978  0.612540      0.548295
#
#                 Shucked weight  Viscera weight  Shell weight     Rings
# Sex                  -0.016457       -0.045292     -0.043825 -0.033272
# Length                0.909245        0.907957      0.914518  0.567074
# ...

# %% [markdown]
# HEATMAP ANALYSIS

# %%
sn.heatmap(cor,annot=True,linewidth=0.1,linecolor='r')
# Out:
# <AxesSubplot:>

# %% [markdown]
# FROM THE INITIAL LOOK ITSELF IT IS CLEAR THAT MULTICOLLINEARITY IS PRESENT

# %% [markdown]
# BELOW PLOT CLEARLY SHOWS THE DEPENDENCY TO TARGET

# %%
plt.figure(figsize=(22,7))
cor['Rings'].sort_values(ascending=False).drop(['Rings']).plot(kind='bar',color='c')
plt.xlabel('Feature',fontsize=14)
plt.ylabel('column with target names',fontsize=14)
plt.title('correlation',fontsize=18)
plt.show()

# %% [markdown]
# from the figure it is clear that shell weight ,height,diameter,lengthwhole weight,viscera weight,
# shucked weight have heigh correlation to rings(target)

# %% [markdown]
# # MULTICOLLINEARITY

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %% [markdown]
# splitting the features and target

# %%
 x=new_df.iloc[:,0:-1]

# %%
x
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0     2.0   0.455     0.365   0.095        0.5140          0.2245
# 1     2.0   0.350     0.265   0.090        0.2255          0.0995
# 2     0.0   0.530     0.420   0.135        0.6770          0.2565
# 3     2.0   0.440     0.365   0.125        0.5160          0.2155
# 4     1.0   0.330     0.255   0.080        0.2050          0.0895
# ...   ...     ...       ...     ...           ...             ...
# 4172  0.0   0.565     0.450   0.165        0.8870          0.3700
# 4173  2.0   0.590     0.440   0.135        0.9660          0.4390
# 4174  2.0   0.600     0.475   0.205        1.1760          0.5255
# 4175  0.0   0.625     0.485   0.150        1.0945          0.5310
# 4176  2.0   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight
# 0             0.1010        0.1500
# 1             0.0485        0.0700
# 2             0.1415        0.2100
# ...

# %%
x.shape
# Out:
# (4027, 8)

# %%
y=new_df.iloc[:,-1]

# %%
y
# Out:
# 0       15
# 1        7
# 2        9
# 3       10
# 4        7
#         ..
# 4172    11
# 4173    10
# 4174     9
# 4175    10
# 4176    12
# Name: Rings, Length: 4027, dtype: int64

# %% [markdown]
# we are defining a  function for vif

# %%
def vif_calc():
    vif=pd.DataFrame()
    vif['VIF Factor']=[variance_inflation_factor(x.values,i)for i in range(x.shape[1])]
    vif['Features']=x.columns
    print(vif)

# %%
vif_calc()
# Out:
#    VIF Factor        Features
# 0    2.586539             Sex
# 1  711.017756          Length
# 2  762.862946        Diameter
# 3   92.050181          Height
# 4  441.600560    Whole weight
# 5  108.511496  Shucked weight
# 6   65.669278  Viscera weight
# 7   94.849108    Shell weight

# %% [markdown]
# by comparing Length and Diameter both have heigh vif value, but here length have less correlated to target
# in the same way i prefer shucked weight also

# %%
new_df.drop(['Length','Shucked weight'],axis=1,inplace=True)

# %%
new_df
# Out:
#       Sex  Diameter  Height  Whole weight  Viscera weight  Shell weight  Rings
# 0     2.0     0.365   0.095        0.5140          0.1010        0.1500     15
# 1     2.0     0.265   0.090        0.2255          0.0485        0.0700      7
# 2     0.0     0.420   0.135        0.6770          0.1415        0.2100      9
# 3     2.0     0.365   0.125        0.5160          0.1140        0.1550     10
# 4     1.0     0.255   0.080        0.2050          0.0395        0.0550      7
# ...   ...       ...     ...           ...             ...           ...    ...
# 4172  0.0     0.450   0.165        0.8870          0.2390        0.2490     11
# 4173  2.0     0.440   0.135        0.9660          0.2145        0.2605     10
# 4174  2.0     0.475   0.205        1.1760          0.2875        0.3080      9
# 4175  0.0     0.485   0.150        1.0945          0.2610        0.2960     10
# 4176  2.0     0.555   0.195        1.9485          0.3765        0.4950     12
#
# [4027 rows x 7 columns]

# %% [markdown]
# multi collinearity is still there but we cant drop further columns

# %% [markdown]
# SCALING FEATURES

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()

# %%
x=sc.fit_transform(x)

# %%
x
# Out:
# array([[ 1.15969763, -0.56936804, -0.42027443, ..., -0.6037333 ,
#         -0.72305677, -0.63065934],
#        [ 1.15969763, -1.47535808, -1.4631268 , ..., -1.20941043,
#         -1.23110406, -1.25603283],
#        [-1.28538214,  0.07776771,  0.15329438, ..., -0.44867996,
#         -0.33113458, -0.16162923],
#        ...,
#        [ 1.15969763,  0.68176107,  0.72686319, ...,  0.85473721,
#          1.08172072,  0.60445329],
#        [-1.28538214,  0.89747298,  0.83114842, ...,  0.88138701,
#          0.82527781,  0.51064727],
#        [ 1.15969763,  1.63089349,  1.56114509, ...,  2.88981235,
#          1.94298183,  2.06626381]])

# %% [markdown]
# # splitting and applying algorithms

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=45)

# %%
x_train.shape
# Out:
# (2818, 8)

# %%
x_test.shape
# Out:
# (1209, 8)

# %%
y_train.shape
# Out:
# (2818,)

# %%
y_test.shape
# Out:
# (1209,)

# %% [markdown]
# LINEAR REGRESSION

# %%
lm=LinearRegression()

# %%
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred=lm.predict(x_test)

# %%
print(pred)
# Out:
# [ 9.00497801  9.9889295   5.78441558 ...  9.36428377  8.92562642
#  11.52153536]

# %% [markdown]
# R2 SCORE

# %%
from sklearn.metrics import r2_score

# %%
lmscore=r2_score(y_test,pred)

# %%
print(lmscore)
# Out:
# 0.5326484752394559

# %% [markdown]
# SVR

# %%
from sklearn.svm import SVR

# %%
svr=SVR(kernel="linear")

# %%
svr.fit(x_train,y_train)
# Out:
# SVR(kernel='linear')

# %%
svrpred=svr.predict(x_test)

# %%
print(svrpred)
# Out:
# [ 8.6185302   9.83228284  5.41199104 ...  8.95078323  8.81655142
#  11.05780084]

# %%
svrscore=r2_score(y_test,svrpred)

# %%
print(svrscore)
# Out:
# 0.5085733876195703

# %% [markdown]
# DECISION TREE

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dtr=DecisionTreeRegressor()

# %%
dtr.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
dtrpred=dtr.predict(x_test)

# %%
print(dtrpred)
# Out:
# [ 6. 11.  5. ... 15.  9.  9.]

# %%
dtrscore=r2_score(y_test,dtrpred)

# %%
print(dtrscore)
# Out:
# 0.13328723032058953

# %% [markdown]
# Kneighbor

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
knnr=KNeighborsRegressor()

# %%
knnr.fit(x_train,y_train)
# Out:
# KNeighborsRegressor()

# %%
knnrpred=knnr.predict(x_test)

# %%
print(knnrpred)
# Out:
# [ 8.8  9.6  5.  ... 12.6  9.4 11.8]

# %%
knnrscore=r2_score(y_test,knnrpred)

# %%
print(knnrscore)
# Out:
# 0.5004575844675865

# %% [markdown]
# different algorithm providind different r2 scores
# to selecting a model we want to check the cross validation mean

# %% [markdown]
# # cross validation mean

# %%
from sklearn.model_selection import cross_val_score

# %%
print(cross_val_score(lm,x,y,cv=5).mean())
# Out:
# 0.41480204014861294

# %%
print(cross_val_score(svr,x,y,cv=5).mean())
# Out:
# 0.4175429588539415

# %%
print(cross_val_score(dtr,x,y,cv=5).mean())
# Out:
# -0.0707489480043673

# %%
print(cross_val_score(knnr,x,y,cv=5).mean())
# Out:
# 0.40530572721736063

# %% [markdown]
# COMPARING THE DIFFERENT VALUES OF R2SCORE AND CROSS VALIDATION MEAN SCORE, HERE SELECTING LINEAR REGRESSION AS THE
# PREFERED ALGORITHM

# %% [markdown]
# # HYPER PARAMETER TUNING

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameter={'fit_intercept':['bool'],
          'normalize':['bool'],
          'copy_X':['bool'],
          'n_jobs':['int']}

# %%
GCV=GridSearchCV(LinearRegression(),parameter,cv=5)

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=LinearRegression(),
#              param_grid={'copy_X': ['bool'], 'fit_intercept': ['bool'],
#                          'n_jobs': ['int'], 'normalize': ['bool']})

# %%
GCV.best_params_
# Out:
# {'copy_X': 'bool',
#  'fit_intercept': 'bool',
#  'n_jobs': 'int',
#  'normalize': 'bool'}

# %%
Finalabalone_model=LinearRegression(copy_X='bool',
 fit_intercept='bool',
 n_jobs='int',
 normalize='bool')

# %%
Finalabalone_model.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X='bool', fit_intercept='bool', n_jobs='int',
#                  normalize='bool')

# %%
Finalpred=Finalabalone_model.predict(x_test)

# %%
Finalr2score=r2_score(y_test,Finalpred)

# %%
print(Finalr2score)
# Out:
# 0.532648475239456

# %% [markdown]
# # SAVING AND CONCLUSION

# %%
Finalconclusion=pd.DataFrame([Finalabalone_model.predict(x_test)[:],Finalpred[:]],index=["Predicted","Orginal"])

# %%
Finalconclusion
# Out:
#                0        1         2         3          4         5     \
# Predicted  9.004978  9.98893  5.784416  8.787723  13.218763  7.767155
# Orginal    9.004978  9.98893  5.784416  8.787723  13.218763  7.767155
#
#                 6         7          8         9     ...      1199       1200  \
# Predicted  13.864523  9.278854  11.096283  14.09076  ...  8.243876  12.175868
# Orginal    13.864523  9.278854  11.096283  14.09076  ...  8.243876  12.175868
#
#                1201      1202       1203       1204      1205      1206  \
# Predicted  8.867991  5.948758  14.066709  12.516363  6.842893  9.364284
# Orginal    8.867991  5.948758  14.066709  12.516363  6.842893  9.364284
#
#                1207       1208
# Predicted  8.925626  11.521535
# Orginal    8.925626  11.521535
#
# [2 rows x 1209 columns]

# %% [markdown]
# SAVING THE MODEL

# %%
import joblib

# %%
joblib.dump(Finalabalone_model,"Finalabalone_model.pk1")
# Out:
# ['Finalabalone_model.pk1']
