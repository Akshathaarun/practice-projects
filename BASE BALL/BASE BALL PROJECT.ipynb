# %% [markdown]
# # BASE BALL PROJECT

# %% [markdown]
# Importing needed libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import norm
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # CHECKING THE DATA ROWS AND COLUMNS

# %%
df=pd.read_csv("Baseball.csv")

# %%
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
df.tail()
# Out:
#      W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 25  92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26  84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27  79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28  74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29  68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV   E
# 25   21  47  75
# 26   18  41  78
# 27   12  44  86
# 28    6  41  92
# 29    4  36  95

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# BY ANALYSING DATA SETS IT IS CLEAR THAT THE FOLLOWING COLUMNS HAVE GREATERMEAN COMPARING MEDIAN:-AB,H,HR,SV,E SO SKEWED DATAS ARE THERE,,,
#     SOME COLUMN LIKE SO HAVE HIGH DATA SPREAD- WHICH HAVING HEIGH STANDARD DEVIATION.,,,

# %%
df.shape
# Out:
# (30, 17)

# %% [markdown]
# dataset has 30 raws and 17 columns

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %% [markdown]
# THE COLIMNS ARE:RUNS,,,AT BATS,,,HITS,,,DOUBLES,,,TRIPLES,,,HOME RUNS,,,WALKS,,,STRIKE OUT,,STOLEN BASE,,,RUNS ALLOWED,,EARNED RUNS,,,EARNED RUNS AVG,,SHUTOUTS,,SAVES

# %% [markdown]
# the target column is w:win

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %% [markdown]
# all column datas are in int or float format

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# there is no null values in datasets

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # DATASET DESCRIPTION

# %% [markdown]
# HERE COLUMNS SHOWS DIFFERENT FACTORS INDICATING THE SUCCESS OF A BASEBALL TEAM, HERE ANALYSING DIFFERENT FACTOR PARAMETERS FOR DIFFERENT TEAMS AND THEIR WINS.
# THE COLIMNS ARE:RUNS,,,AT BATS,,,HITS,,,DOUBLES,,,TRIPLES,,,HOME RUNS,,,WALKS,,,STRIKE OUT,,STOLEN BASE,,,RUNS ALLOWED,,EARNED RUNS,,,EARNED RUNS AVG,COMPLETE GAMES,SHUTOUTS,,SAVES,ERRORS

# %% [markdown]
# SHAPE OF DATASET IS 30*17,,30 RAWS AND 17 COLUMNS
# HERE TARGET COLUMN IS W:WIN NUMBER OF PREDICTED,,, THERE IS NO NULL VARAIABLE IN THE DATASET..
#     ALL DATASET ARE IN INT AND FLOAT TYPE

# %% [markdown]
# # EDA

# %% [markdown]
# # ANALYSING TARGET

# %%
df['W'].unique()
# Out:
# array([ 95,  83,  81,  76,  74,  93,  87,  80,  78,  88,  86,  85,  68,
#        100,  98,  97,  64,  90,  71,  67,  63,  92,  84,  79])

# %%
sns.displot(df['W'])

# %% [markdown]
# THESE ARE THE DIFFERENT VALUES IN THE TARGET CLASS 95,  83,  81,  76,  74,  93,  87,  80,  78,  88,  86,
# 85,  68,100,  98,  97,  64,  90,  71,  67,  63,  92,  84,79

# %% [markdown]
# HERE VALUES IN THE RANGE OF 75-80 HOLDING HEIGH COUNT AND VALUES IN THE RANGE 70-75 HAVE LEAT COUNTS.
# BOTH 65-70,AND 85-90 HAVING ALMOST EQUAL COUNTS LIKE VALUES BETWEEN 90-95 AND 95-100

# %% [markdown]
# BY ANALYSING TARGET IT IS CLEAR THAT WE HAVE TO IMPLEMENT REGRESSION ALGORITHMS FOR MODEL PREDICTIONS

# %% [markdown]
# # FEATURE COLUMNS:UNIVARIATE ANALYSIS

# %% [markdown]
# R:RUNS

# %%
sns.displot(df['R'])

# %% [markdown]
# RUNS ARE DISTRIBUTED ALMOST NORMALLY,BUT THERE IS NO CONTINUATION IN THE DATA

# %% [markdown]
# AB:At Bats

# %%
sns.displot(df['AB'])

# %% [markdown]
# AB is distributed normally

# %% [markdown]
# H:hits

# %%
sns.displot(df['H'])

# %% [markdown]
# H is distributed almost normally but negative skewness is there

# %% [markdown]
# 2B:DOUBLES

# %%
sns.displot(df['2B'])

# %% [markdown]
# 2B is distributed normally

# %% [markdown]
# 3B:TRIPLES

# %%
sns.displot(df['3B'])

# %% [markdown]
# 3B is almost normally distributed

# %% [markdown]
# HR:HomeRuns

# %%
sns.displot(df['HR'])

# %% [markdown]
# HR is almost normally distributed

# %% [markdown]
# BB:WALKS

# %%
sns.displot(df['BB'])

# %% [markdown]
# BB IS ALMOST DISTRIBUTED NORMALLY HOWEVER SLIGHT NEGATIVE SKEWNESS IS THERE

# %% [markdown]
# SO:STRIKE OUTS

# %%
sns.displot(df['SO'])

# %% [markdown]
# SO IS NORMALLY DISTRIBUTED

# %% [markdown]
# SB:STRIKE BACK

# %%
sns.displot(df['SB'])

# %% [markdown]
# SB IS DISTRIBUTED NORMALLY

# %% [markdown]
# RA:RUNS ALLOWED

# %%
sns.displot(df['RA'])

# %% [markdown]
# RA IS DISTRIBUTING NORMALLY

# %% [markdown]
# ER:EARNED RUNS

# %%
sns.displot(df['ER'])

# %% [markdown]
# ER ALSO DISTRIBUTED NORMALLY

# %% [markdown]
# ERA:ER AVERAGE

# %%
sns.displot(df['ERA'])

# %% [markdown]
# ERA IS PERFECTLY NORMAL DISTRIBUTED

# %% [markdown]
# CG:COMPLETE GAME

# %%
sns.displot(df['CG'])

# %% [markdown]
# CG HAS NEGATIVE SKEWNESS

# %% [markdown]
# SHO:SHUTOUTS

# %%
sns.displot(df['SHO'])

# %% [markdown]
# SHO IS NORMALLY DISTRIBUTED

# %% [markdown]
# SV:SAVES

# %%
sns.displot(df['SV'])

# %% [markdown]
# SV IS ALMOST NORMALLY DISTRIBUTED

# %% [markdown]
# E:ERRORS

# %%
sns.displot(df['E'])

# %% [markdown]
# E IS NORMALLY DISTRIBUTED

# %% [markdown]
# BI_VARIATE ANALYSIS

# %%
plt.figure(figsize=[10,6])
plt.title('compare RUNS AND DOUBLES')
sns.scatterplot(df['R'],df['2B'],hue=df['W'])
# Out:
# <AxesSubplot:title={'center':'compare RUNS AND DOUBLES'}, xlabel='R', ylabel='2B'>

# %% [markdown]
# PLOT OF RUNS AND DOUBLES ARE ALMOST LINEAR PROPOTION

# %%
plt.figure(figsize=[10,6])
plt.title('compare RUNS AND TRIPLES')
sns.scatterplot(df['R'],df['3B'],hue=df['W'])
# Out:
# <AxesSubplot:title={'center':'compare RUNS AND TRIPLES'}, xlabel='R', ylabel='3B'>

# %% [markdown]
# PLOT SHOWS THE RELATION BETWEEN RUN AND TRIPLETS

# %%
plt.figure(figsize=[10,6])
plt.title('compare HITS AND RUNS')
sns.scatterplot(df['H'],df['R'],hue=df['W'])
# Out:
# <AxesSubplot:title={'center':'compare HITS AND RUNS'}, xlabel='H', ylabel='R'>

# %% [markdown]
# RELATION BETWEEN HITS AND RUNS ARE LINEARLY PROPOTION TO EACH OTHER

# %%
plt.figure(figsize=[10,6])
plt.title('EARNED RUNS RUNS AND ER AVG')
sns.scatterplot(df['ER'],df['ERA'],hue=df['W'])
# Out:
# <AxesSubplot:title={'center':'EARNED RUNS RUNS AND ER AVG'}, xlabel='ER', ylabel='ERA'>

# %% [markdown]
# PLOT SHOWS THE LINEAR RELATION BETWEEN EARNED RUND AND EARNED RUNS AVG

# %%
plt.figure(figsize=[10,6])
plt.title(' RUNS AND HOME RUNS')
sns.scatterplot(df['R'],df['HR'],hue=df['W'])
# Out:
# <AxesSubplot:title={'center':' RUNS AND HOME RUNS'}, xlabel='R', ylabel='HR'>

# %% [markdown]
# ABOVE SCATTER PLOT SHOWS THE RELATION BETWEEN RUNS AND HOME RUNS

# %%
plt.figure(figsize=[10,6])
plt.title('RUNS ALLOWED AND EARNED RUNS')
sns.scatterplot(df['RA'],df['ER'],hue=df['W'])
# Out:
# <AxesSubplot:title={'center':'RUNS ALLOWED AND EARNED RUNS'}, xlabel='RA', ylabel='ER'>

# %% [markdown]
# RUNS ALOWED AND EARNED RUNS HAVE LINEAR RELATION

# %%
plt.figure(figsize=[10,6])
plt.title('EARNED RUNS RUNS AND HOME RUNS')
sns.scatterplot(df['HR'],df['ER'],hue=df['W'])
# Out:
# <AxesSubplot:title={'center':'EARNED RUNS RUNS AND HOME RUNS'}, xlabel='HR', ylabel='ER'>

# %% [markdown]
# EARNED RUNS AND HOME RUNS NOT HAVE PARTICULAR RELATION

# %%
plt.figure(figsize=[10,6])
plt.title('EARNED RUNS RUNS AND HOME RUNS')
sns.scatterplot(df['AB'],df['ER'],hue=df['W'])
# Out:
# <AxesSubplot:title={'center':'EARNED RUNS RUNS AND HOME RUNS'}, xlabel='AB', ylabel='ER'>

# %% [markdown]
# AT BATS AND EARNED RUNS  PLOT SHON ABOVE

# %%
plt.figure(figsize=[10,6])
plt.title('AT BATS AND EARNED RUN AVG')
sns.scatterplot(df['AB'],df['ERA'],hue=df['W'])
# Out:
# <AxesSubplot:title={'center':'AT BATS AND EARNED RUN AVG'}, xlabel='AB', ylabel='ERA'>

# %%
plt.figure(figsize=[10,6])
plt.title('COMPARISON BETWEEN EARNED RUNS AND WINS')
sns.scatterplot(df['RA'],df['W'],hue=df['W'])
# Out:
# <AxesSubplot:title={'center':'COMPARISON BETWEEN EARNED RUNS AND WINS'}, xlabel='RA', ylabel='W'>

# %% [markdown]
# plot shows the comparison of eraned runs and win

# %%
plt.figure(figsize=[10,6])
plt.title('RUNS AND WINS')
sns.scatterplot(df['R'],df['W'])
# Out:
# <AxesSubplot:title={'center':'RUNS AND WINS'}, xlabel='R', ylabel='W'>

# %% [markdown]
# ABOVE PLOT SHOWING THE RDELATION OF RUNS AND WIN

# %%
plt.figure(figsize=[10,6])
plt.title('COMPARISON OF HITS AND  RUNS')
sns.scatterplot(df['H'],df['R'],hue=df['W'])
# Out:
# <AxesSubplot:title={'center':'COMPARISON OF HITS AND  RUNS'}, xlabel='H', ylabel='R'>

# %% [markdown]
# ABOVE FIGURE SHOWS RELATION OF HITS AND RUN

# %%
sns.pairplot(df,hue="W")

# %% [markdown]
# ABOVE PAIR PLOTS SHOWS THE RELATION AMONG DIFFERENT CLASSES

# %% [markdown]
# # CHECKING OUTLIERS

# %% [markdown]
# BOX PLOT

# %%
sns.boxplot(df['R'])
# Out:
# <AxesSubplot:xlabel='R'>

# %% [markdown]
# R HAS A SLIGHT OUTLIER PRESENCE

# %%
sns.boxplot(df['AB'])
# Out:
# <AxesSubplot:xlabel='AB'>

# %% [markdown]
# THERE IS NO OUTLIER FOR AB

# %%
sns.boxplot(df['H'])
# Out:
# <AxesSubplot:xlabel='H'>

# %% [markdown]
# THERE IS NO OUTLIER IN H

# %%
sns.boxplot(df['2B'])
# Out:
# <AxesSubplot:xlabel='2B'>

# %% [markdown]
# THERE IS NO OUTLIER IN 2B

# %%
sns.boxplot(df['3B'])
# Out:
# <AxesSubplot:xlabel='3B'>

# %% [markdown]
# THERE IS NO OUTLIER IN 3B

# %%
sns.boxplot(df['HR'])
# Out:
# <AxesSubplot:xlabel='HR'>

# %% [markdown]
# HR ALSO HAVE NO OPUTLIER PRESENCE

# %%
sns.boxplot(df['BB'])
# Out:
# <AxesSubplot:xlabel='BB'>

# %% [markdown]
# BB HAS NO OUTLIERS

# %%
sns.boxplot(df['SO'])
# Out:
# <AxesSubplot:xlabel='SO'>

# %% [markdown]
# SO HAS NO OUTLIER PRESENCE

# %%
sns.boxplot(df['SB'])
# Out:
# <AxesSubplot:xlabel='SB'>

# %% [markdown]
# SB HAS NO OUTLIER IN PLOT

# %%
sns.boxplot(df['RA'])
# Out:
# <AxesSubplot:xlabel='RA'>

# %%
sns.boxplot(df['ER'])
# Out:
# <AxesSubplot:xlabel='ER'>

# %% [markdown]
# ER HAS NO OUTLIER PRESENCE

# %%
sns.boxplot(df['ERA'])
# Out:
# <AxesSubplot:xlabel='ERA'>

# %% [markdown]
# THERE IS OUTLIER IN ERA

# %%
sns.boxplot(df['SV'])
# Out:
# <AxesSubplot:xlabel='SV'>

# %% [markdown]
# SV HAS OUTLIER

# %%
sns.boxplot(df['SHO'])
# Out:
# <AxesSubplot:xlabel='SHO'>

# %% [markdown]
# SHO HAS OUTLIER

# %%
sns.boxplot(df['CG'])
# Out:
# <AxesSubplot:xlabel='CG'>

# %% [markdown]
# CG DONT HAVE OUTLIER

# %%
sns.boxplot(df['E'])
# Out:
# <AxesSubplot:xlabel='E'>

# %% [markdown]
# LOTS OF OUTLIERS ARE THERE IN E

# %% [markdown]
# # DATA PREPROCESSING

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# SOME COLUMNS SHOWS AN HUGE DIFFERENCE BETWEEN 75% AND MAX VALUE,SO PRESENCE OF OUTLIER IS THERE

# %% [markdown]
# # OUTLIER REMOVAL

# %%
df.shape
# Out:
# (30, 17)

# %%
from scipy.stats import zscore

# %%
z=np.abs(zscore(df))

# %%
new_df=df[(z<3).all(axis=1)]

# %%
new_df.shape
# Out:
# (29, 17)

# %% [markdown]
# LOSS CALCULATION

# %% [markdown]
# 1/30 % OF LOSS IS VERY LESS AND CAN PROCEED

# %% [markdown]
# # CHECKING SKEWNESS

# %%
new_df.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.783772
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG     0.854980
# SHO    0.526943
# SV     0.627480
# E      0.840271
# dtype: float64

# %% [markdown]
# THE COLUMNS "H","CG","E" HAVING SKEWNESS PRESENCE

# %% [markdown]
# ANALYSING SKEWNESS WITH HISTOGRAM

# %%
new_df['H'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# SKEWNESS IS CLEARV IN HISTOGRAM PLOT OF"H"

# %%
new_df['E'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# "E"ALSO HAVING  SKEWNESS

# %%
new_df['CG'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# HITOGRAM PLOT OF CG CLEARLY CONVEYS SKEWNESS

# %% [markdown]
# REMOVING SKEWNESS

# %%
from scipy import sqrt

# %%
new_df["CG"]=np.sqrt(new_df["CG"])

# %%
new_df["E"]=np.sqrt(new_df["E"])

# %%
new_df["H"]=np.sqrt(new_df["H"])

# %%
new_df.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.761274
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG    -0.260678
# SHO    0.526943
# SV     0.627480
# E      0.714966
# dtype: float64

# %%
new_df['CG'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# CLEARLY SKEWNESS REMOVED

# %%
new_df['H'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
FROM H ALSO SKEWNES REMOVED
# Out:
#   File "<ipython-input-77-a7373a73e757>", line 1
#     FROM H ALSO SKEWNES REMOVED
#          ^
# SyntaxError: invalid syntax

# %%
new_df['E'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# SKEWNESS IS REMOVED FROM "E"

# %% [markdown]
# NOW SKEWNESS VALUE BECOME IN ACCEPTABLE RANGE

# %% [markdown]
# CORRELATION AND HEAT MAP

# %%
cor=new_df.corr()

# %%
cor
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.390451 -0.085780 -0.019562  0.384886 -0.206737  0.245697
# R    0.390451  1.000000  0.438022  0.432903  0.469293  0.134204  0.586894
# AB  -0.085780  0.438022  1.000000  0.769684  0.490752  0.445604 -0.064653
# H   -0.019562  0.432903  0.769684  1.000000  0.527700  0.580906 -0.218968
# 2B   0.384886  0.469293  0.490752  0.527700  1.000000  0.342419 -0.098695
# 3B  -0.206737  0.134204  0.445604  0.580906  0.342419  1.000000 -0.369299
# HR   0.245697  0.586894 -0.064653 -0.218968 -0.098695 -0.369299  1.000000
# BB   0.447513  0.258450 -0.137850 -0.222036  0.211243 -0.404852  0.336814
# SO   0.156469  0.081158 -0.111243 -0.372596 -0.096772 -0.196586  0.479914
# SB  -0.169503  0.075323  0.373674  0.419058  0.194308  0.483818 -0.166072
# RA  -0.823176 -0.013858  0.315499  0.244127 -0.215196  0.312750 -0.092586
# ER  -0.815308  0.007727  0.309146  0.280268 -0.224993  0.333731 -0.062094
# ...

# %% [markdown]
# HEAT MAP

# %%
plt.figure(figsize=(30,15))
sns.heatmap(cor,annot=True,linewidths=0.1,linecolor="black",fmt="0.2f")
# Out:
# <AxesSubplot:>

# %% [markdown]
# CHECKING THE TARGET DEPENDENCY

# %%
plt.figure(figsize=(22,7))
cor['W'].sort_values(ascending=False).drop(['W']).plot(kind='bar',color='c')
plt.xlabel('Feature',fontsize=14)
plt.ylabel('column with target names',fontsize=14)
plt.title('correlation',fontsize=18)
plt.show()

# %% [markdown]
# BY ANALYSING THE PLOTS OF CORRELATION AND HEAT MAP, IT CONVEYS THE PRESENCE OF MULTI COLLINEARITY.
# SOME COLUMNS LIKE"RA"."ER","ERA" SHOWING CORRELATION TO EACH OTHER

# %% [markdown]
# # MULTI COLLINEARITY

# %% [markdown]
# # SEPARATING COLUMNS FOR X AND Y

# %%
x=new_df.drop("W",axis=1)
y=new_df["W"]

# %%
x
# Out:
#       R    AB          H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  \
# 0   724  5575  38.691084  300  42  139  383   973  104  641  601  3.73
# 1   696  5467  36.728735  277  44  156  439  1264   70  700  653  4.07
# 2   669  5439  37.349699  303  29  141  533  1157   86  640  584  3.67
# 3   622  5533  37.161808  260  27  136  404  1231   68  701  643  3.98
# 4   689  5605  38.923001  289  49  151  455  1259   83  803  746  4.64
# 6   764  5567  37.376463  272  19  212  554  1227   63  698  652  4.03
# 7   713  5485  37.013511  246  20  217  418  1331   44  693  646  4.05
# 8   644  5485  37.188708  278  32  167  436  1310   87  642  604  3.74
# 9   748  5640  38.665230  294  33  161  478  1148   71  753  694  4.31
# 10  751  5511  37.669616  279  32  172  503  1233  101  733  680  4.24
# 11  729  5459  36.918830  278  26  230  486  1392  121  618  572  3.57
# 12  661  5417  36.482873  243  21  176  435  1150   52  675  630  3.94
# ...

# %%
x.shape
# Out:
# (29, 16)

# %%
y
# Out:
# 0      95
# 1      83
# 2      81
# 3      76
# 4      74
# 6      87
# 7      81
# 8      80
# 9      78
# 10     88
# 11     86
# 12     85
# 13     76
# 14     68
# 15    100
# 16     98
# 17     97
# 18     68
# 19     64
# 20     90
# 21     83
# 22     71
# 23     67
# 24     63
# 25     92
# 26     84
# 27     79
# 28     74
# 29     68
# Name: W, dtype: int64

# %%
y.shape
# Out:
# (29,)

# %% [markdown]
# # VIF

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
def vif_calc():
    vif=pd.DataFrame()
    vif['VIF Factor']=[variance_inflation_factor(x.values,i)for i in range(x.shape[1])]
    vif['Features']=x.columns
    print(vif)

# %%
vif_calc()
# Out:
#       VIF Factor Features
# 0    1492.195391        R
# 1   22162.910164       AB
# 2   22770.730393        H
# 3     891.616708       2B
# 4      35.860064       3B
# 5     260.117302       HR
# 6     269.823524       BB
# 7     409.721616       SO
# 8      28.901562       SB
# 9   17802.920590       RA
# 10  43268.282118       ER
# 11  22125.696425      ERA
# 12     12.219107       CG
# 13     31.466153      SHO
# 14    109.541389       SV
# 15    416.762761        E

# %% [markdown]
# SOME COLUMNS HAVE HEIGH VIF VALUES DROPPING SOME COLUMNS

# %%
new_df.drop(["ER"],axis=1,inplace=True)

# %%
new_df.drop(["H"],axis=1,inplace=True)

# %%
new_df.drop(["AB"],axis=1,inplace=True)

# %%
new_df
# Out:
#       W    R   2B  3B   HR   BB    SO   SB   RA   ERA        CG  SHO  SV  \
# 0    95  724  300  42  139  383   973  104  641  3.73  1.414214    8  56
# 1    83  696  277  44  156  439  1264   70  700  4.07  1.414214   12  45
# 2    81  669  303  29  141  533  1157   86  640  3.67  3.316625   10  38
# 3    76  622  260  27  136  404  1231   68  701  3.98  2.645751    9  37
# 4    74  689  289  49  151  455  1259   83  803  4.64  2.645751   12  35
# 6    87  764  272  19  212  554  1227   63  698  4.03  1.732051    4  48
# 7    81  713  246  20  217  418  1331   44  693  4.05  0.000000   10  43
# 8    80  644  278  32  167  436  1310   87  642  3.74  1.000000   12  60
# 9    78  748  294  33  161  478  1148   71  753  4.31  1.732051   10  40
# 10   88  751  279  32  172  503  1233  101  733  4.24  2.236068    9  45
# 11   86  729  278  26  230  486  1392  121  618  3.57  2.236068   13  39
# 12   85  661  243  21  176  435  1150   52  675  3.94  1.414214   12  46
# ...

# %%
x=new_df.drop("W",axis=1)
y=new_df["W"]

# %%
x
# Out:
#       R   2B  3B   HR   BB    SO   SB   RA   ERA        CG  SHO  SV          E
# 0   724  300  42  139  383   973  104  641  3.73  1.414214    8  56   9.380832
# 1   696  277  44  156  439  1264   70  700  4.07  1.414214   12  45   9.273618
# 2   669  303  29  141  533  1157   86  640  3.67  3.316625   10  38   8.888194
# 3   622  260  27  136  404  1231   68  701  3.98  2.645751    9  37  10.049876
# 4   689  289  49  151  455  1259   83  803  4.64  2.645751   12  35   9.273618
# 6   764  272  19  212  554  1227   63  698  4.03  1.732051    4  48   9.643651
# 7   713  246  20  217  418  1331   44  693  4.05  0.000000   10  43   8.774964
# 8   644  278  32  167  436  1310   87  642  3.74  1.000000   12  60   9.746794
# 9   748  294  33  161  478  1148   71  753  4.31  1.732051   10  40   9.848858
# 10  751  279  32  172  503  1233  101  733  4.24  2.236068    9  45  10.908712
# 11  729  278  26  230  486  1392  121  618  3.57  2.236068   13  39   9.219544
# ...

# %%
y
# Out:
# 0      95
# 1      83
# 2      81
# 3      76
# 4      74
# 6      87
# 7      81
# 8      80
# 9      78
# 10     88
# 11     86
# 12     85
# 13     76
# 14     68
# 15    100
# 16     98
# 17     97
# 18     68
# 19     64
# 20     90
# 21     83
# 22     71
# 23     67
# 24     63
# 25     92
# 26     84
# 27     79
# 28     74
# 29     68
# Name: W, dtype: int64

# %% [markdown]
# # SCALING

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()

# %%
x=sc.fit_transform(x)

# %%
x
# Out:
# array([[ 0.95939835,  1.55653766,  1.01084549, -0.76586314, -1.53635899,
#         -2.72762331,  0.9059529 , -0.66451353, -0.51138828, -0.25354897,
#         -0.81326172,  1.64315663, -0.45432526],
#        [ 0.33114717,  0.20117132,  1.20891656, -0.18138864, -0.49502051,
#          0.12189552, -0.58531515,  0.15463823,  0.23895226, -0.25354897,
#          0.15929869,  0.21100645, -0.60761852],
#        [-0.27466646,  1.73332457, -0.2766165 , -0.69710144,  1.25294051,
#         -0.9258657 ,  0.11645805, -0.67839746, -0.64380131,  2.02046293,
#         -0.32698152, -0.70036184, -1.15869812],
#        [-1.32923093, -0.8006212 , -0.47468758, -0.8690057 , -1.14585706,
#         -0.20124579, -0.6730368 ,  0.16852216,  0.04033271,  1.21854679,
#         -0.57012162, -0.83055731,  0.50227443],
#        [ 0.17408438,  0.90831897,  1.70409425, -0.35329291, -0.19749523,
#          0.07293472, -0.01512442,  1.58468284,  1.4968761 ,  1.21854679,
#          0.15929869, -1.09094826, -0.60761852],
# ...

# %% [markdown]
# # splitting and applying regression algorithm

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=45)

# %%
x_train.shape
# Out:
# (20, 13)

# %%
x_test.shape
# Out:
# (9, 13)

# %%
y_test.shape
# Out:
# (9,)

# %%
y_train.shape
# Out:
# (20,)

# %% [markdown]
# # linear regression

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
lm=LinearRegression()

# %%
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred=lm.predict(x_test)

# %%
print(pred)
# Out:
# [81.98303755 83.19014739 93.65450044 64.92145256 81.27821443 81.31859697
#  56.25167007 91.38854944 90.52656074]

# %% [markdown]
# errors

# %%
print("mean absolute error:",mean_absolute_error(y_test,pred))
# Out:
# mean absolute error: 6.8858735027571685

# %%
print("mean squred error:",mean_squared_error(y_test,pred))
# Out:
# mean squred error: 84.51992845831994

# %%
print("root mean squared error:",np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# root mean squared error: 9.19347205675418

# %% [markdown]
# r2 score

# %%
from sklearn.metrics import r2_score

# %%
lmscore=r2_score(y_test,pred)

# %%
print(lmscore)
# Out:
# -0.01664897610987759

# %% [markdown]
# # SUPPORT VECTOR REGRESSION

# %%
from sklearn.svm import SVR

# %%
svr=SVR(kernel="linear")

# %%
svr.fit(x_train,y_train)
# Out:
# SVR(kernel='linear')

# %%
svrpred=svr.predict(x_test)

# %%
print(svrpred)
# Out:
# [78.85222279 88.87280913 89.9091333  68.35879477 82.21593586 79.26152955
#  67.25829677 84.61506348 74.32112316]

# %% [markdown]
# ERRORS

# %%
print("mean absolute error:",mean_absolute_error(y_test,svrpred))
# Out:
# mean absolute error: 3.6619043146905046

# %%
print("mean squred error:",mean_squared_error(y_test,svrpred))
# Out:
# mean squred error: 24.937615220612855

# %%
print("root mean squared error:",np.sqrt(mean_squared_error(y_test,svrpred)))
# Out:
# root mean squared error: 4.9937576253371425

# %% [markdown]
# R2 SCORE

# %%
svrscore=r2_score(y_test,svrpred)

# %%
print(svrscore)
# Out:
# 0.7000375953564536

# %% [markdown]
# # DECISION TREE REGRESSION

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dtr=DecisionTreeRegressor()

# %%
dtr.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
dtrpred=dtr.predict(x_test)

# %%
print(dtrpred)
# Out:
# [83. 98. 90. 74. 90. 78. 63. 83. 76.]

# %% [markdown]
# ERRORS

# %%
print("mean absolute error:",mean_absolute_error(y_test,dtrpred))
# Out:
# mean absolute error: 6.444444444444445

# %%
print("mean squred error:",mean_squared_error(y_test,dtrpred))
# Out:
# mean squred error: 64.22222222222223

# %%
print("root mean squared error:",np.sqrt(mean_squared_error(y_test,dtrpred)))
# Out:
# root mean squared error: 8.013876853447538

# %% [markdown]
# R2 SCORE

# %%
dtrscore=r2_score(y_test,dtrpred)

# %%
print(dtrscore)
# Out:
# 0.22750222750222748

# %% [markdown]
# # K-NEIGHBOUR

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
knnr=KNeighborsRegressor()

# %%
knnr.fit(x_train,y_train)
# Out:
# KNeighborsRegressor()

# %%
knnrpred=knnr.predict(x_test)

# %%
print(knnrpred)
# Out:
# [76.6 89.  86.  71.4 82.4 75.8 73.2 82.  75.8]

# %% [markdown]
# ERRORS

# %%
print("mean absolute error:",mean_absolute_error(y_test,knnrpred))
# Out:
# mean absolute error: 6.177777777777779

# %%
print("mean squred error:",mean_squared_error(y_test,knnrpred))
# Out:
# mean squred error: 46.622222222222234

# %%
print("root mean squared error:",np.sqrt(mean_squared_error(y_test,knnrpred)))
# Out:
# root mean squared error: 6.828046735503663

# %% [markdown]
# R2 SCORE

# %%
knnrscore=r2_score(y_test,knnrpred)

# %%
print(knnrscore)
# Out:
# 0.43920403920403905

# %% [markdown]
# # CROSS VALIDATION MEAN

# %%
from sklearn.model_selection import cross_val_score

# %%
print(cross_val_score(lm,x,y,cv=5).mean())
# Out:
# 0.32343711755888144

# %%
print(cross_val_score(svr,x,y,cv=5).mean())
# Out:
# 0.34283629310116204

# %%
print(cross_val_score(dtr,x,y,cv=5).mean())
# Out:
# -2.4066763413297787

# %%
print(cross_val_score(knnr,x,y,cv=5).mean())
# Out:
# -0.11791424927818346

# %% [markdown]
# ANALYSING ALGORITHMS

# %% [markdown]
# BY analysing different algorithms and different parameters like r2 score error values and cross validation
# it is clear that svr is comparatively better ,,so it is prefering for further proceedings

# %% [markdown]
# # HYPER PARAMETER TUNING FOR SUPPORT VECTOR REGRESSOR

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameter={'kernel':['linear','poly'],
          'gamma':['scale','auto'],
          'C':[0.01,0.1,1,10],'epsilon':[0.0001,0.001,0.01,0.1]}

# %%
GCV=GridSearchCV(SVR(kernel="linear"),parameter,cv=5)

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=SVR(kernel='linear'),
#              param_grid={'C': [0.01, 0.1, 1, 10],
#                          'epsilon': [0.0001, 0.001, 0.01, 0.1],
#                          'gamma': ['scale', 'auto'],
#                          'kernel': ['linear', 'poly']})

# %%
GCV.best_params_
# Out:
# {'C': 1, 'epsilon': 0.1, 'gamma': 'scale', 'kernel': 'linear'}

# %%
Finalbaseball_model=SVR(C =1, epsilon = 0.1, gamma = 'scale',kernel = 'linear')

# %%
Finalbaseball_model.fit(x_train,y_train)
# Out:
# SVR(C=1, kernel='linear')

# %%
Finalpred=Finalbaseball_model.predict(x_test)

# %%
Finalr2score=r2_score(y_test,Finalpred)

# %%
print(Finalr2score)
# Out:
# 0.7000375953564536

# %% [markdown]
# # SAVING AND CONCLUSION

# %%
conclusion=pd.DataFrame([Finalbaseball_model.predict(x_test)[:],Finalpred[:]],index=["Predicted","Orginal"])

# %%
conclusion
# Out:
#                    0          1          2          3          4         5  \
# Predicted  78.852223  88.872809  89.909133  68.358795  82.215936  79.26153
# Orginal    78.852223  88.872809  89.909133  68.358795  82.215936  79.26153
#
#                    6          7          8
# Predicted  67.258297  84.615063  74.321123
# Orginal    67.258297  84.615063  74.321123

# %% [markdown]
# SAVING THE MODEL

# %%
import joblib

# %%
joblib.dump(Finalbaseball_model,"Finalbaseball_model.pk1")
# Out:
# ['Finalbaseball_model.pk1']
